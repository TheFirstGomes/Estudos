# %%
import pandas as pd

# %%
url = r'C:\Users\Usuario\Documents\Estudos\FIAP\Estudos\ALURA\03_Curso_Pandas_Inicial\raw\1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx'
emissoes_gases = pd.read_excel(url, sheet_name='GEE Estados')
# Out:
# c:\Users\Usuario\Documents\Estudos\FIAP\Estudos\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
emissoes_gases['Nível 1 - Setor'].unique()
# Out:
# array(['Processos Industriais', 'Agropecuária', 'Energia', 'Resíduos ',
#        'Mudança de Uso da Terra e Floresta'], dtype=object)

# %%
emissoes_gases['Estado'].unique()
# Out:
# array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#        'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#        'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object)

# %%
len(emissoes_gases['Estado'].unique())
# Out:
# 29

# %%
emissoes_gases[emissoes_gases['Estado'].isin(['PR', 'SC', 'RS'])]
# Out:
#                            Nível 1 - Setor              Nível 2  \
# 35                   Processos Industriais    Indústria Química
# 36                   Processos Industriais    Indústria Química
# 37                   Processos Industriais    Indústria Química
# 110                  Processos Industriais    Produtos Minerais
# 111                  Processos Industriais    Produtos Minerais
# ...                                    ...                  ...
# 103221  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103222  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103223  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103224  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103225  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                     Nível 3 Nível 4       Nível 5 Nível 6  \
# 35       Produção de Amônia     NaN           NaN     NaN
# 36       Produção de Amônia     NaN           NaN     NaN
# ...

# %%
emissoes_gases[(emissoes_gases['Estado'] == 'AM') & (emissoes_gases['Nível 1 - Setor'] == 'Mudança de Uso da Terra e Floresta')]
# Out:
#                            Nível 1 - Setor                     Nível 2  \
# 81262   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81271   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81280   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81289   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81298   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# ...                                    ...                         ...
# 102803  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102812  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102821  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102830  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102839  Mudança de Uso da Terra e Floresta         Resíduos Florestais
#
#          Nível 3                 Nível 4       Nível 5  \
# 81262   Amazônia  fora de Área Protegida  Desmatamento
# ...

# %%
emissoes_gases.loc[(emissoes_gases['Nível 1 - Setor'] == 'Agropecuária') & (emissoes_gases['Estado'] == 'PA'), 2021].max()
# Out:
# np.float64(36856969.7986)

# %%
emissoes_gases.groupby('Nível 1 - Setor').groups
# Out:
# {'Agropecuária': [1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, ...], 'Energia': [24735, 24736, 24737, 24738, 24739, 24740, 24741, 24742, 24743, 24744, 24745, 24746, 24747, 24748, 24749, 24750, 24751, 24752, 24753, 24754, 24755, 24756, 24757, 24758, 24759, 24760, 24761, 24762, 24763, 24764, 24765, 24766, 24767, 24768, 24769, 24770, 24771, 24772, 24773, 24774, 24775, 24776, 24777, 24778, 24779, 24780, 24781, 24782, 24783, 24784, 24785, 24786
# ...

# %%
emissoes_gases.groupby('Nível 1 - Setor').get_group('Agropecuária')
# Out:
#       Nível 1 - Setor           Nível 2  Nível 3  \
# 1137     Agropecuária  Cultivo de Arroz  Diretas
# 1138     Agropecuária  Cultivo de Arroz  Diretas
# 1139     Agropecuária  Cultivo de Arroz  Diretas
# 1140     Agropecuária  Cultivo de Arroz  Diretas
# 1141     Agropecuária  Cultivo de Arroz  Diretas
# ...               ...               ...      ...
# 24730    Agropecuária   Solos Manejados  Diretas
# 24731    Agropecuária   Solos Manejados  Diretas
# 24732    Agropecuária   Solos Manejados  Diretas
# 24733    Agropecuária   Solos Manejados  Diretas
# 24734    Agropecuária   Solos Manejados  Diretas
#
#                                         Nível 4  Nível 5  \
# 1137                                     Outros  Vegetal
# 1138                                     Outros  Vegetal
# 1139                                     Outros  Vegetal
# 1140                                     Outros  Vegetal
# 1141                                     Outros  Vegetal
# ...

# %%
emissoes_por
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 emissoes_gases.groupby(['Nível 1 - Setor', '2021']).sum(numeric_only=True)
#
# File c:\Users\Usuario\Documents\Estudos\FIAP\Estudos\.venv\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...
