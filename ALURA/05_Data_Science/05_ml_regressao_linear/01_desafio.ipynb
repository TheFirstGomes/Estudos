# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px
from sklearn.model_selection import train_test_split

# %%
url = r'C:\Users\Usuario\Documents\Estudos\ALURA\05_Data_Science\raw\hoteis.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Estrelas  ProximidadeTurismo  Capacidade       Preco
# 0         5            9.301565           3  506.275452
# 1         1            1.785891           1  246.363458
# 2         4           15.504293           3  325.873550
# 3         4            4.173188           3  521.343284
# 4         4            9.443685           1  252.587087

# %%
sns.pairplot(data=df, y_vars='Preco', x_vars=['Estrelas', 'ProximidadeTurismo', 'Capacidade'], kind='scatter', diag_kind='hist');

# %%
X = df.drop(columns=['Preco'])
y = df['Preco']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=10)

# %%
import statsmodels.api as sm

modelo_1 = sm.OLS(y_train, sm.add_constant(X_train)).fit()
modelo_2 = sm.OLS(y_train, sm.add_constant(X_train[['Estrelas']])).fit()
modelo_3 = sm.OLS(y_train, sm.add_constant(X_train[['Estrelas', 'Capacidade']])).fit()
modelo_4 = sm.OLS(y_train, sm.add_constant(X_train[['Estrelas', 'ProximidadeTurismo']])).fit()

# %%
print("Modelo 1:", modelo_1.summary())
# Out:
# Modelo 1:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Preco   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     2421.
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):               0.00
# Time:                        20:10:59   Log-Likelihood:                -3438.8
# No. Observations:                 650   AIC:                             6886.
# Df Residuals:                     646   BIC:                             6904.
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                194.5736      6.839     28.449      0.000     181.144     208.004
# Estrelas              49.6705      1.347     36.872      0.000      47.025      52.316
# ProximidadeTurismo   -20.0939      0.328    -61.333      0.000     -20.737     -19.451
# Capacidade            82.2352      1.718     47.854      0.000      78.861      85.610
# ==============================================================================
# Omnibus:                        2.508   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.285   Jarque-Bera (JB):                2.236
# Skew:                          -0.055   Prob(JB):                        0.327
# Kurtosis:                       2.734   Cond. No.                         37.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Modelo 2:", modelo_2.summary())
# Out:
# Modelo 2:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Preco   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     106.7
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):           2.96e-23
# Time:                        20:11:03   Log-Likelihood:                -4203.4
# No. Observations:                 650   AIC:                             8411.
# Df Residuals:                     648   BIC:                             8420.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        261.5154     14.414     18.143      0.000     233.212     289.819
# Estrelas      44.9610      4.353     10.329      0.000      36.413      53.509
# ==============================================================================
# Omnibus:                        8.536   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.712
# Skew:                          -0.271   Prob(JB):                       0.0128
# Kurtosis:                       2.833   Cond. No.                         8.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Modelo 3:", modelo_3.summary())
# Out:
# Modelo 3:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Preco   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     256.9
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):           7.60e-83
# Time:                        20:11:05   Log-Likelihood:                -4062.9
# No. Observations:                 650   AIC:                             8132.
# Df Residuals:                     647   BIC:                             8145.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.9997     16.595      2.410      0.016       7.413      72.586
# Estrelas      48.7846      3.516     13.876      0.000      41.881      55.688
# Capacidade    83.8654      4.485     18.700      0.000      75.059      92.672
# ==============================================================================
# Omnibus:                       46.135   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.079
# Skew:                          -0.683   Prob(JB):                     1.81e-12
# Kurtosis:                       3.359   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Modelo 4:", modelo_4.summary())
# Out:
# Modelo 4:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Preco   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     547.8
# Date:                Tue, 13 Jan 2026   Prob (F-statistic):          6.26e-140
# Time:                        20:11:06   Log-Likelihood:                -3930.9
# No. Observations:                 650   AIC:                             7868.
# Df Residuals:                     647   BIC:                             7881.
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                413.5969     10.826     38.203      0.000     392.338     434.856
# Estrelas              45.9327      2.865     16.034      0.000      40.307      51.558
# ProximidadeTurismo   -20.3363      0.698    -29.143      0.000     -21.707     -18.966
# ==============================================================================
# Omnibus:                      105.084   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.555
# Skew:                          -0.023   Prob(JB):                     4.65e-06
# Kurtosis:                       2.049   Cond. No.                         27.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
